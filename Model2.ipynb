# %% [markdown]
# <a href="https://colab.research.google.com/github/farookfazni/AI-to-Predict-Career-Path/blob/master/Model2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# if sapcy is not there
# !pip install spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      |████████████████████████████████| 13.9 MB 13.2 MB/s
# ...
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en-core-web-sm 2.2.5
#     Uninstalling en-core-web-sm-2.2.5:
#       Successfully uninstalled en-core-web-sm-2.2.5
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
import pandas as pd

# %%
nlp = spacy.load("en_core_web_sm")

# %%
Data = pd.read_csv('/content/drive/MyDrive/Research Dataset/processed_data/Added_Target/FullyMerged.csv')

# %%
Data.head()
# Out:
#    Unnamed: 0                                  id  \
# 0           0                      gayanchinthaka
# 1           1  kashita-niranjan-udayanga-04106a47
# 2           2   lingeswaran-sivapiriyan-b90685177
# 3           3             viraj-chamara-5b6751149
# 4           4           iyani-kalupahana-5b781951
#
#                                               skills  \
# 0  Java Android Development PHP HTML C Cascading ...
# 1                                                ...
# 2  JavaScript Reactjs MySQL ObjectOriented Progra...
# 3  Java JavaScript PHP HTML Cascading Style Sheet...
# 4  Java Android Development C Communication HTML ...
#
#                                                edu_1  \
# 0  Computer Science and Technology Uva Wellassa U...
# 1       BSc Engineering(Hons) University of Moratuwa
# 2  B.Eng (Hons) Software Engineering  London Metr...
# 3         Institute of Java and Software Engineering
# 4  Honours Degree of Bachelor of the Science of E...
#
# ...

# %%
Data = Data.drop(['Unnamed: 0'], axis=1)

# %%
Data.head()
# Out:
#                                    id  \
# 0                      gayanchinthaka
# 1  kashita-niranjan-udayanga-04106a47
# 2   lingeswaran-sivapiriyan-b90685177
# 3             viraj-chamara-5b6751149
# 4           iyani-kalupahana-5b781951
#
#                                               skills  \
# 0  Java Android Development PHP HTML C Cascading ...
# 1                                                ...
# 2  JavaScript Reactjs MySQL ObjectOriented Progra...
# 3  Java JavaScript PHP HTML Cascading Style Sheet...
# 4  Java Android Development C Communication HTML ...
#
#                                                edu_1  \
# 0  Computer Science and Technology Uva Wellassa U...
# 1       BSc Engineering(Hons) University of Moratuwa
# 2  B.Eng (Hons) Software Engineering  London Metr...
# 3         Institute of Java and Software Engineering
# 4  Honours Degree of Bachelor of the Science of E...
#
#                                           edu_2  \
# ...

# %%
# !pip install dframcy
# dframcy = DframCy(nlp)
# Data_doc = dframcy.nlp(Data)

# %%
Data['ALL'] = Data[['skills','edu_1','edu_2','edu_3','org_1','org_2','org_3','org_4']].agg(' '.join, axis=1)

# %%
Data_all = Data.iloc[:,9:]
Data_all
# Out:
#                  Target                                                ALL
# 0     Software Engineer  Java Android Development PHP HTML C Cascading ...
# 1     Software Engineer                                                ...
# 2     Software Engineer  JavaScript Reactjs MySQL ObjectOriented Progra...
# 3     Software Engineer  Java JavaScript PHP HTML Cascading Style Sheet...
# 4     Software Engineer  Java Android Development C Communication HTML ...
# ...                 ...                                                ...
# 4571       Data Science  SQL Git Machine Learning C Deep Learning Pytho...
# 4572       Data Science  Python Programming Language Bootstrap Machine ...
# 4573       Data Science  Java C JavaScript PHP MySQL Cascading Style Sh...
# 4574       Data Science  Python Programming Language HTML Machine Learn...
# 4575       Data Science  SQL Data Analysis Microsoft Excel Deep Learnin...
#
# [4576 rows x 2 columns]

# %%
Data_all['tokenized_ALL'] = Data_all['ALL'].apply(lambda x: nlp(x))
Data_all
# Out:
#                  Target                                                ALL  \
# 0     Software Engineer  Java Android Development PHP HTML C Cascading ...
# 1     Software Engineer                                                ...
# 2     Software Engineer  JavaScript Reactjs MySQL ObjectOriented Progra...
# 3     Software Engineer  Java JavaScript PHP HTML Cascading Style Sheet...
# 4     Software Engineer  Java Android Development C Communication HTML ...
# ...                 ...                                                ...
# 4571       Data Science  SQL Git Machine Learning C Deep Learning Pytho...
# 4572       Data Science  Python Programming Language Bootstrap Machine ...
# 4573       Data Science  Java C JavaScript PHP MySQL Cascading Style Sh...
# 4574       Data Science  Python Programming Language HTML Machine Learn...
# 4575       Data Science  SQL Data Analysis Microsoft Excel Deep Learnin...
#
#                                           tokenized_ALL
# ...
