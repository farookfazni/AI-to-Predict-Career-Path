# %% [markdown]
# <a href="https://colab.research.google.com/github/farookfazni/AI-to-Predict-Career-Path/blob/master/MOB_Cyber_DEV_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
MOB = pd.read_csv('/content/drive/MyDrive/Research Dataset/processed_data/Cleaned_Data_Step1/MOB_processed1.csv')
Cyber = pd.read_csv('/content/drive/MyDrive/Research Dataset/processed_data/Cleaned_Data_Step1/Cyber_processed1.csv')
DEV = pd.read_csv('/content/drive/MyDrive/Research Dataset/processed_data/Cleaned_Data_Step1/DEV_processed1.csv')

# %%
MOB_title = pd.read_csv('/content/drive/MyDrive/Research Dataset/processed_data/Fully_Extracted_Data/MOB_processed1.csv')
Cyber_title = pd.read_csv('/content/drive/MyDrive/Research Dataset/processed_data/Fully_Extracted_Data/Cyber_processed1.csv')
DEV_title = pd.read_csv('/content/drive/MyDrive/Research Dataset/processed_data/Fully_Extracted_Data/Dev_processed1.csv')

# %%
Cyber_title['organization_title_1']
# Out:
# 0                                   Director
# 1                                   Director
# 2      Associate Consultant - Cyber Security
# 3                  Cyber Security Consultant
# 4                          Managing Director
#                        ...
# 629    Associate Consultant - Cyber Security
# 630                        Visiting Lecturer
# 631       Senior Branch Operations Assistant
# 632    Intern - Information Security Analyst
# 633                  Cyber Security Engineer
# Name: organization_title_1, Length: 634, dtype: object

# %%
MOB_Data = pd.concat([MOB,MOB_title['organization_title_1']], axis=1)
Cyber_Data = pd.concat([Cyber,Cyber_title['organization_title_1']], axis=1)
DEV_Data = pd.concat([DEV,DEV_title['organization_title_1']], axis=1)

# %%
# Drop column
MOB_Data = MOB_Data.drop(['Unnamed: 0','Unnamed: 0.1'], axis=1)
Cyber_Data = Cyber_Data.drop(['Unnamed: 0','Unnamed: 0.1'], axis=1)
DEV_Data = DEV_Data.drop(['Unnamed: 0','Unnamed: 0.1'], axis=1)

# %%
def check_Avalaiblity(datset,x="Software Engineer"):
  countpos = 0
  countneg = 0
  other_labels = []
  label = []
  # goimg through the datset
  for i in datset['organization_title_1']:
    # making sure all values are string
    st = str(i)
    # cheking the sub string exisits in string
    if x in st:
      # if sting is available adding 1 to label
      label.append(1)
      # Keep count
      countpos += 1
    else:
      # if sting is not available adding 0 to label
      label.append(0)
      # adding the values of other string values to the other_label
      other_labels.append(st)
      countneg += 1
  return label, other_labels, countpos, countneg

# %%
Cyber_Data

# %%
label, other_labels, countpos, countneg = check_Avalaiblity(Cyber_Data,"Cyber Security")

# %%
other_labels

# %%
Cyber_Data = Cyber_Data.dropna(subset=['organization_title_1'])

# %%
label, other_labels, countpos, countneg = check_Avalaiblity(Cyber_Data,"Cyber Security")

# %%
countneg
# Out:
# 351

# %%
other_labels
# Out:
# ['Director',
#  'Director',
#  'Managing Director',
#  'Director - Hacktify Community',
#  'Systems and Network Engineer',
#  'President',
#  'Executive – Information Technology',
#  'Quality Assurance Engineer',
#  'Assistant Vice President - Information Security',
#  'Information Security Analyst',
#  'Technology Advisory Associate',
#  'Chair of the Executive Committee',
#  'Chief Operating Officer',
#  'Freelance Video Editor',
#  'Chief Technology Officer',
#  'Engineer | Network & Information Security',
#  'Regional Office - Chief Information Security Officer',
#  'Associate Engineer\xa0Systems & Security ',
#  'Chief Security Editor',
#  'Intern',
#  'Associate Security Enginner',
#  'Network and Security Engineer',
#  'Information Security',
#  'Implementation Engineering Intern - Information Security ',
#  'Internship Trainee',
#  'Head Of Digital Marketing',
#  'Content Creator',
#  'Support and Curation',
#  'Technical Support Executive',
#  'ASSOCIATE JUNIOR NETWORK ENGINEER',
#  'Information Systems Audit Associate',
#  'Programmer',
#  'Intern - IT Infrastructure ',
#  'Trainee Medical Scriber',
#  'Fiverr',
#  'Director',
#  'Photographer',
#  'Ambassador',
#  'CEO',
#  'Senior Executive level II',
#  'System Administrator',
#  'Owner',
#  'Application Engineer',
#  'Information security Trainee ',
#  'Director',
#  'Music Producer',
#  'Security Analyst',
#  'CEO',
#  'Undergraduate',
#  'Software Engineer',
#  'Infrastructure Engineer',
#  'Diploma Student',
#  'Academic Instructor',
#  'Web Developer',
#  'Officer Operations ',
#  'Director',
#  'founder ',
#  'cyber security intern',
#  'Consultant',
#  'Co-Founder',
#  'Executive - Information Security',
#  'Youtube Content Creator',
#  'Undergraduate Student',
#  'Undergraduate',
#  'Founder & Ceo',
#  'Associate Business Analyst',
#  'Specialist Threat & Vulnerability Management ',
#  'Red Team Member and Vulnerability Analyst & Penetration Tester',
#  'Country Director - Sri Lanka',
#  'Compliance and Penetration Testing',
#  'Engineer - Information Security Compliance',
#  'Immediate Past President ',
#  'Information Security Officer',
#  'Senior Manager – Cyber security',
#  'Senior Information Security Analyst (SOC)- Tier 2',
#  'System Administrator',
#  'Senior IT Specialist – Information Security and Compliance @ MJF Group',
#  'Technology Advisory Lead',
#  'Senior Engineer',
#  'Associate Technical Lead',
#  'Senior Solution Strategist',
#  'Chief Cyber-Security & Operations Officer/Senior Consultant',
#  'Associate Security Engineer',
#  'Software Engineer',
#  'Assistant Network Engineer',
#  'IT Specialist',
#  'Software Architect',
#  'Associate Engineer - Information Security',
#  'Senior Network Engineer',
#  'Information Security Analyst',
#  'Chief Information Security Officer (CISO)',
#  'Data Privacy Manager',
#  'Senior Systems Engineer - DevOps',
#  'Freelance Graphic Designer',
#  'Business Relationship Manager',
#  'Senior Systems Administrator',
#  'Web Developer',
#  'Graphic Designer',
#  'Intern - Information Systems Auditor',
#  'Associate',
#  'Intern : ICT',
#  'Graphic Designer & Photographer',
#  'IT GRC',
#  'Intern',
#  'Intern',
#  'Program Team Deputy Head',
#  'Trainee',
#  'IT Audit',
#  'SLIIT CHESS CLUB',
#  'Founder',
#  'Founder',
#  'IT Executive',
#  'Chief Executive & Technology Officer',
#  'Cyber Threat Investigator',
#  'DevOps - IoT & Middleware',
#  'Head Of Information Technology',
#  'Programmer',
#  'CEO',
#  'Manager - IT Infrastructure',
#  'Chief Information Security Officer',
#  'Network Security Engineer',
#  'Senior Manager - Technology Risk and Support',
#  'Information Security Engineer',
#  'Trainee system operator',
#  'Trainee Information Security',
#  'Managing Director',
#  'Information Technology Administrator',
#  'Manager Grade IV - Programming',
#  'Visiting Lecturer',
#  'Digital Services - Management Trainee',
#  'Marketing Assistant',
#  'Undergraduate Student',
#  'Blogger and owner',
#  'Sales Engineer',
#  'Chief Executive Officer',
#  'Music Producer',
#  'Associate Information Security Analyst',
#  'Technical Consultant',
#  'Freelance Admin Assistant',
#  'Senior Manager',
#  'A/L ICT Tutor',
#  'Freelance',
#  'Information Technology Analyst',
#  'Intern',
#  'Engineer - Information Security',
#  'Senior Associate Consultant',
#  'Managing Director and CEO',
#  'Full Stack Developer',
#  'Founder',
#  'Solutions Architect',
#  'Security Engineer',
#  'Deputy Manager - Cyber Threat Intelligence & Security Monitoring',
#  'Senior Information Security Analyst - Tier 2',
#  'IT Specialist',
#  'Director',
#  'Data Governance Manager',
#  'Threat Manager - Security Operations',
#  'Mentor',
#  'Social Media Manager',
#  'Level 2 Security Operation Centre Analyst/ Consultant Information Security',
#  'Consultant - Network & Security',
#  'Information Risk Management -  IT Auditor',
#  'Software Engineer - HSBC Securities Services at HSBC Global Banking and Markets ',
#  'Udemy Instructor',
#  'UX/UI Designer',
#  'Associate Information Security Analyst ',
#  'Associate Consultant',
#  'Site Reliability Engineer',
#  'SOC Analyst',
#  'Information Security Executive',
#  'Senior Technical Consultant - Sri Lanka & Maldives',
#  'Company Managing Director /CEO At ',
#  'Consultant',
#  'Security operations Center manager',
#  'Senior Engineer - Systems/Cloud (Global Consulting)',
#  'Technical Specialist',
#  'Security Operations Centre (SOC) Engineer - Level 1',
#  'General Manager',
#  'Organizer',
#  'Senior Client Partner',
#  'Software Engineer',
#  'Network Associate - Information Security ',
#  'Member',
#  'Intern- Red Teaming',
#  'Junior Executive Assistant ',
#  'Team Manager',
#  'Senior Engineering Specialist',
#  'Information Security Intern',
#  'Software Engineer',
#  'Engineering Trainee',
#  'QA Engineer',
#  'Information Technology Manager',
#  'Sub Committee Member',
#  'Graphic Designer',
#  'Web Designer',
#  'Associate Image Processor',
#  'Consultant',
#  'Till The Long Lost Dream Job Come True',
#  'Founder and CEO',
#  'Security Researcher',
#  'Information Technology Support Officer',
#  'Lead IT Governance and Business Continuity',
#  'Co-Founder and Chief Information Security Officer',
#  'Information System Security Officer',
#  'Lecturer at Spy legends',
#  'President',
#  'Chief Information Security Officer',
#  'Operations Engineer - Global Technology Operations Command Center',
#  'SOC Analyst',
#  'Senior Manager Information Technology ',
#  'Board Member',
#  'Assistant Librarian',
#  'Technical Specialist',
#  'SOC Analyst',
#  ' Engineer, Service Desk, ITSM Operations',
#  'Information Technology Officer',
#  'no job',
#  'Lecturer (Temporary)',
#  'Trainee Information Security Engineer',
#  'Undergraduate',
#  'CEO',
#  'Web Designer',
#  'Chief Executive Officer ',
#  'Director',
#  'SOC',
#  'Security Operations Center Analyst',
#  'Supervisor',
#  'University Lecturer',
#  'Associate Engineer',
#  'System Engineer',
#  'Founder',
#  'Chief Executive Officer',
#  'Chief Editor',
#  'Cyber security Intern',
#  'Assistant',
#  'Cyber security intern',
#  'school leaver',
#  'Assistant Director',
#  'IT Security and Compliance Intern ',
#  'Information Technology Instructor',
#  'Oracle ERP administrator',
#  'Undergraduate Student',
#  'Internship Trainee - System Engineering ',
#  'Security Analyst',
#  'Customer Support Executive',
#  'Member',
#  'Country security Leader',
#  'Senior Information Security Analyst',
#  'Associate Consultant - Information Security ',
#  'Executive Information Security Governance',
#  'Information Security Analyst',
#  'Founder & CEO',
#  'System Engineer',
#  'Senior Business Analyst',
#  'Deputy Manager - Lead Auditor Information Security',
#  'Chief Marketing Officer',
#  'Cyber Risk Committee',
#  'Advisory Board Member',
#  'Information Security Analyst Intern',
#  'Freelance IT Security Researcher',
#  'Information Technology  / InfoSec',
#  'Visiting Lecturer',
#  'Associate Engineer - Information Security at CryptoGen',
#  'Assistant Manager IT',
#  'Senior DevOps Engineer',
#  'Founder & CEO',
#  'Associate System Engineer - Security',
#  'Information Security Assurance Analyst ',
#  'Assistant Manager - IS Audit',
#  'Founder',
#  'Information Security Analyst | Incident Handling & Awareness',
#  'Senior Engineer- Systems & Security',
#  'Bug Bounty Hunter',
#  'Senior Electrical and Electronics Engineer & Satge Manager',
#  'Associate System Engineer',
#  'Tech Lead-Network ',
#  'Chief Information Security Officer ',
#  'Information Security Engineer',
#  'Quality Assurance Analyst',
#  'Account manager - Strategic Accounts',
#  'Associate Site Reliability Engineer',
#  'Information security Intern',
#  'Senior System Engineer - Security Technologies',
#  'Associate Information Security Analyst',
#  'Business Development Executive',
#  'Full Stack Javascript Developer ',
#  'Co-Founder & CEO',
#  'Information Security',
#  'Intern - Information Security',
#  'IT/ Information Security Governance, Risk & Compliance',
#  'President',
#  'Chief Operating Officer (COO)',
#  'SOC Analyst',
#  'Student',
#  'Personal Trainer',
#  'Advisor',
#  'Director - Chief Technical Officer',
#  'Digital Marketing Manager',
#  'Managing Director',
#  'Information Security Center Director ',
#  'Officer',
#  'Information Technology System Administrator Intern',
#  'Graduated',
#  'IT Infrasturcture Operations Specialist',
#  'General Manager & Head of India Center',
#  'DevOps Intern',
#  'cyber security engineer',
#  'Associate Executive Engineer – Information Security',
#  'President / CEO / Founder ',
#  'Head - Products & Technology ',
#  'Student',
#  'Software Engineer',
#  'Chief Executive Officer',
#  'Information Security Intern',
#  'Director',
#  'Infrastructure Engineer',
#  'Lecturer',
#  'Security Analyst',
#  'Chief Technology Officer',
#  'Website Administr',
#  'Vice President',
#  'Network Engineer',
#  'Penetration Testing Intern',
#  'Professional Web Designer (Freelance)',
#  'Co-Founder and Managing Director',
#  'President / CEO',
#  'COO ',
#  'Network Administrator',
#  'Junior Analyst',
#  'Chairman Of The Board',
#  'Group Executive Director',
#  'Artist',
#  'Committee Member',
#  'IT Consultant',
#  'Undergraduate',
#  'Price Scanning',
#  'Cyber expert',
#  'Industrial Trainee Experienced System security team',
#  'Information Systems Security Analyst',
#  'Senior Software Engineer',
#  'OperaInterntions Security Intern',
#  'UI Designer',
#  'Customer Service Executive',
#  'Management Information Analyst',
#  'Intern',
#  'Security Researcher',
#  'Operations Officer',
#  'CEO',
#  'Visiting Lecturer',
#  'Senior Branch Operations Assistant',
#  'Intern - Information Security Analyst']

# %%
Cyber_Data['label'] = label
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
Cyber_Data_New = Cyber_Data.loc[Cyber_Data['label']==0]

# %%
Cyber_Data_New.shape
# Out:
# (351, 11)

# %%
pd.set_option('max_rows', 99999)
pd.set_option('max_colwidth', 400)
pd.describe_option('max_colwidth')
# Out:
# display.max_colwidth : int or None
#     The maximum width in characters of a column in the repr of
#     a pandas data structure. When the column overflows, a "..."
#     placeholder is embedded in the output. A 'None' value means unlimited.
#     [default: 50] [currently: 400]

# %%
Cyber_Data_New
# Out:
#                                              id  ... label
# 0                                   danielsingh  ...     0
# 1                                 imeshliyanage  ...     0
# 4                        jagathpathi-rajapakshe  ...     0
# 6                                         shifa  ...     0
# 13                supun-wickramatilake-302a7033  ...     0
# 18                                gayanvirantha  ...     0
# 26                    sankalpa-nirmana-24032286  ...     0
# 36                                    bilal-007  ...     0
# 37                                   kiyasudeen  ...     0
# 39                   sadeepa-gayashan-9575a517b  ...     0
# 44                   ranjan-weerakoon-502a11118  ...     0
# 45                                       rahalj  ...     0
# 46                               shafraz-asnavi  ...     0
# 48                sachintha-weesinghe-6b0494138  ...     0
# 49                               kasundananjaya  ...     0
# 51                                  buddhimamax  ...     0
# 52                             sahanseneviratne  ...     0
# 55                                sonali-anesta  ...     0
# 59                              priya-gbhackers  ...     0
# 60                                   hasintha98  ...     0
# 65                     lasith-hettige-b2024a12a  ...     0
# 66                         ramya-shantha-peiris  ...     0
# 67               nimani-karunathilaka-896421209  ...     0
# 68                               ruweeniddagoda  ...     0
# 70                                    7a5728192  ...     0
# 73                                    shamryyyy  ...     0
# 75                     thushan-jaliya-3b1507202  ...     0
# 77                              arshad-sabireen  ...     0
# 78                                  rajitha2day  ...     0
# 79                      mohamed-rinaz-b541b7146  ...     0
# 80      keshani-arundathi-bogahawatte-b0b965147  ...     0
# 86         maheraj-thiruvanantharajah-33459316a  ...     0
# 88                            hansi-b-a26325171  ...     0
# 91                   pabasara-bandara-980aa3208  ...     0
# 94                              tharana-hansaja  ...     0
# 96                                     alisterj  ...     0
# 98                  sandev-hettiwatta-a2578a1a9  ...     0
# 100                    pathum-pradeep-4310aa172  ...     0
# 103                            tim-heath-238193  ...     0
# 106                 buddhika-madushan-57a57a10b  ...     0
# 107                  ezhilan-baskaran-170116185  ...     0
# 112                            medhaviprathibha  ...     0
# 113                 sumudu-subhashini-3a057814b  ...     0
# 114                               nethminavodya  ...     0
# 115                     jassim-ismail-95ab78110  ...     0
# 116                           nikhila-hansanath  ...     0
# 117                      nalinda-silva-208361b9  ...     0
# 118                            cybersecurityinc  ...     0
# 122                dasunpriya-kalhara-5a59b1162  ...     0
# 124                      isuri-herath-372a791b0  ...     0
# 125               h-v-sachini-lakmali-08257717b  ...     0
# 128      kavusikan-kawshi-sivayogarasa-4a385ab3  ...     0
# 129                          gothami-jayasinghe  ...     0
# 130                       mohamed-ijas-570b43ba  ...     0
# 140                             shenelifernando  ...     0
# 141                  ravindu-porutota-61a451188  ...     0
# 142                    cyber-security-1a59a9184  ...     0
# 143                sandali-wijesinghe-569397186  ...     0
# 146             pranidhi-handapangoda-708942205  ...     0
# 156                            udarairanasinghe  ...     0
# 157                    sumala-mannage-a22994184  ...     0
# 158                       rafi-riswan-909672215  ...     0
# 160          imesh-dilshan-rajakaruna-7310a620a  ...     0
# 162                 sachintha-sampath-a43894218  ...     0
# 163           pentlock-cyber-security-04a0a7225  ...     0
# 167                  hirasha-shouketh-0224a4200  ...     0
# 170                            bawanthachandula  ...     0
# 175                  chamod-wijetunga-b4a803150  ...     0
# 178                                   aselawaid  ...     0
# 180                 yasiru-jayasinghe-723475138  ...     0
# 183                             naweenwelihinda  ...     0
# 185                                     sithira  ...     0
# 186                                    yoshika4  ...     0
# 187                                    wddensil  ...     0
# 188                              ashanmaduranga  ...     0
# 189                  chalaka-jayaweera-83aa8383  ...     0
# 190                           security-engineer  ...     0
# 191                         subagini-sivaseelan  ...     0
# 195                                 samanguruge  ...     0
# 196                  suresh-rupasinghe-48922853  ...     0
# 199                          chithamparanathanr  ...     0
# 201                                    oshadhiw  ...     0
# 202              dhanusha-wijayaweera-73075b166  ...     0
# 203                           sandunamarathunga  ...     0
# 205                          sadeepa-prabhasara  ...     0
# 207                    mohammed-friyal-37b89759  ...     0
# 208                     kavinda-herath-58728076  ...     0
# 209                              pasindu-dissan  ...     0
# 210                              mohamed-rezard  ...     0
# 211         mahesh-menaka-senavirathna-5a68b483  ...     0
# 212                                    kasunpgb  ...     0
# 214           arani-srinivasan-reshzan-5a03144a  ...     0
# 215                             roshanthamalaka  ...     0
# 216                lohith-gunawardena-161031182  ...     0
# 217                     udara-laknatha-7b07bb76  ...     0
# 218                              wyugthadesilva  ...     0
# 219                  meth-gunawardana-a3b958201  ...     0
# 220                       sujampathi-rathnayaka  ...     0
# 222                          vimukthiwishvajith  ...     0
# 223                  devsith-fernando-4833031a3  ...     0
# 224                            isurudilshanlive  ...     0
# 226                       dilan-nonis-747528141  ...     0
# 227                   jayani-chamodhi-24397a1a1  ...     0
# 228                  rashini-de-zoysa-64868a203  ...     0
# 229                               ansiriwardena  ...     0
# 230            adeeptha-hettiarachchi-2aa1581b1  ...     0
# 233            sharin-lakni-pinnapola-748914151  ...     0
# 234                 imesh-karandeniya-227470205  ...     0
# 236                   hiranya-keshara-720b4a1b4  ...     0
# 238  cyber-security-training-platform-b53553164  ...     0
# 239                          shubhamangalasunil  ...     0
# 240               shanaka-lankathilaka-7a85319a  ...     0
# 241                      harish-ramani-60a08915  ...     0
# 245                     homal-fernando-aa2156a3  ...     0
# 250                          oshanikarunarathna  ...     0
# 253                charitha-munasinghe-40a97257  ...     0
# 254                manoj-arunathilaka-b70b78119  ...     0
# 256                              nazar-tymoshyk  ...     0
# 257                                 aadilahamed  ...     0
# 258                                  shahsheikh  ...     0
# 263                sampath-badullawage-8bb50aab  ...     0
# 265                         amal-wickramasinghe  ...     0
# 266                                 thusithak94  ...     0
# 270                     isuru-tharuka-332349175  ...     0
# 275            joanna-sarah-edwardraj-750997206  ...     0
# 277        cyber-security-australasia-a10124198  ...     0
# 279                             oshadaviduranga  ...     0
# 281                   indika-sirimanna-4065b923  ...     0
# 285                  yasas-geethanjana-2631138b  ...     0
# 286             kaushika-alahapperuma-b93590158  ...     0
# 287                  sachini-fernando-4035a017b  ...     0
# 290                chamodh-karunamuni-a9b78b16b  ...     0
# 291                          malshan-rathnayake  ...     0
# 292                            nipungunathilaka  ...     0
# 296                   buddhi-chalanga-952069149  ...     0
# 297                rushanka-rajapakse-681aa71b2  ...     0
# 299                             danujaatulugama  ...     0
# 302                  chamika-koralege-49b723141  ...     0
# 304                          praneeth-manoharan  ...     0
# 305                      pasan-perera-4894b81a0  ...     0
# 311                             ihenakaarachchi  ...     0
# 315             raguraj-srirajeswaran-88b626168  ...     0
# 322      shaluka-sankalpa-leelarathna-b32b9821a  ...     0
# 329                                   ahthirulm  ...     0
# 331                             ashan-kobewatta  ...     0
# 332                     asiri-ishantha-0069027a  ...     0
# 333                     rakesh-asthana-5a40665a  ...     0
# 335                                   damon-fdo  ...     0
# 337                             ruwin-ratnayake  ...     0
# 338           chamara-pathum-madawala-911198100  ...     0
# 339                                    sinmayan  ...     0
# 341                                   lahiru962  ...     0
# 342                    lodum-senaratne-1a903338  ...     0
# 343                     charana-shenal-444106b8  ...     0
# 344                       abhijit-parab-9a1ba74  ...     0
# 347                                    hasithak  ...     0
# 348                                  daredumidu  ...     0
# 352                      avinash-kadam-94958311  ...     0
# 353                  chamodi-abisheka-998abb112  ...     0
# 354                                   sridarsri  ...     0
# 357                      anojithan-pakkiyarajah  ...     0
# 358                      ausaff-amaan-095238130  ...     0
# 362                 samira-senanayake-4b7b66110  ...     0
# 363                                     lakmalr  ...     0
# 364                          hashikajayawardana  ...     0
# 365                                     dinidhu  ...     0
# 366              dinusha-jayawardhana-268b4a158  ...     0
# 367                               sampathhewage  ...     0
# 368                           amaal-edirisinghe  ...     0
# 369                  md-hasan-mahmud-r-85452ab1  ...     0
# 370                         neranjandissanayake  ...     0
# 372                   hazzan-ahamed🇱🇰-376a1910b  ...     0
# 374                    chirath-ranwala-546069b4  ...     0
# 375                          waruna-samaraweera  ...     0
# 376                    dulan-algiriya-519012109  ...     0
# 377                             swarnakadesilva  ...     0
# 378                                   anjalee-u  ...     0
# 379                              lindsaypereira  ...     0
# 380                               sureshmichael  ...     0
# 381                   shalini-hansika-457ab91a9  ...     0
# 383                           akalanka-jayalath  ...     0
# 384                                      rdinu1  ...     0
# 385                osuni-abeywickrama-2a7b66209  ...     0
# 386              hansindu-maniyangama-352b951a2  ...     0
# 387                                ramindusoysa  ...     0
# 388               tharindu-sandaruwan-3523a11b9  ...     0
# 389                 shanaka-bogaswatte-734a9049  ...     0
# 390       andrew-heshan-vihan-udawela-a8971b208  ...     0
# 391             suganthan-balasuriyan-06363816b  ...     0
# 392                    kavindu-viraj-r-7b9732b8  ...     0
# 394                               srikanth20141  ...     0
# 395                                      dinuja  ...     0
# 396                               wenupamandinu  ...     0
# 397                    pasindu-anjana-5b854720b  ...     0
# 399                               nayananjaleer  ...     0
# 401                                   chamodnir  ...     0
# 405                   cyber-security-milindtech  ...     0
# 406              sandamal-gunawardana-4ba218147  ...     0
# 408                               bartbarcewicz  ...     0
# 410      pubudu-priyashan-iddamalgoda-172494145  ...     0
# 411                thusitha-tennakoon-2881ab1b2  ...     0
# 412                                  nalinudesh  ...     0
# 413                               glennbsweeney  ...     0
# 415                viraj-samaranayaka-19ab92166  ...     0
# 416                         ami-elazari-0a78852  ...     0
# 419                      jeremy-miller-2902561b  ...     0
# 420                     togai-andrews-7aa7b9192  ...     0
# 421                    naadhish-yahya-a35b76156  ...     0
# 422             kalana-kathriarachchi-64a614142  ...     0
# 425                              aravindaboteju  ...     0
# 426                      rachael-falk-779069153  ...     0
# 427                  nerandi-kumburage-20147b49  ...     0
# 430                     bakeer-hassan-3476a5134  ...     0
# 434                               shahani-silva  ...     0
# 436                             damiennadarajah  ...     0
# 437                   tharidu-dilshan-830773134  ...     0
# 439               eranda-thibbotuwawa-585a08162  ...     0
# 440                sammani-rajapaksha-2569ab165  ...     0
# 441                  aloka-ranasinghe-3ba5381b4  ...     0
# 442                kithmini-thathsara-2194601a2  ...     0
# 443                                    nir-duan  ...     0
# 445                pasindu-balasuriya-153598114  ...     0
# 446                            simon-hepburn-ma  ...     0
# 448                                     gigiraf  ...     0
# 449             thilina-dharmakeerthi-19833b18b  ...     0
# 452                  dasitha-maduranga-6261bb40  ...     0
# 453                     chiran-sayuru-24a039195  ...     0
# 456                              hansanimperera  ...     0
# 458                    anuka-jinadasa-823655180  ...     0
# 460              mayura-wickramarathna-2174472b  ...     0
# 461                         protoncybersecurity  ...     0
# 462                   shamaal-panagoda-87b01623  ...     0
# 465           thanura-manjitha-peiris-244124198  ...     0
# 466                   umindu-liyanage-352522172  ...     0
# 468                     aadhil-muneef-2498ab1b5  ...     0
# 471                   shanon-fernando-306359207  ...     0
# 472              emika-chamodi-wasana-83180b20a  ...     0
# 475                rageesh-yogeswaran-755470167  ...     0
# 476                  nisadi-kularatne-46428a1a2  ...     0
# 477                                  siva01pksh  ...     0
# 478                  mohamed-thasneem-672633175  ...     0
# 479                     kushan-bhagya-4a81441b2  ...     0
# 480               kalpana-dissanayake-77033b229  ...     0
# 484               wenuja-kodithuwakku-498720224  ...     0
# 487         anthony-mackenzi-fernando-8b36a6214  ...     0
# 488                      sajani-m-keerthisinghe  ...     0
# 490              madushan-jayathilaka-0520a4188  ...     0
# 491                                 karavinthan  ...     0
# 493               thivaharan-ratnathas-822192b4  ...     0
# 494               anuradha-morapitiya-419481129  ...     0
# 495               nadun-wickramasekara-49b36597  ...     0
# 497                            prabeshchoudhary  ...     0
# 498                             nuwanpeirislive  ...     0
# 499                        chamindra-h-948a8b2b  ...     0
# 500                   amila-wijerathne-93224934  ...     0
# 502                       smita-singh-642a8b181  ...     0
# 503                                      p-kang  ...     0
# 507                           john-meakin-52ba2  ...     0
# 509                                      zdeera  ...     0
# 510           shen-tharindu-senanayake-1a46bbb5  ...     0
# 511                              mohamedniamath  ...     0
# 512                        shalinda-weerasinghe  ...     0
# 513                vinura-gunathilaka-99ab4514a  ...     0
# 514                  anushka-maduranga-0032696b  ...     0
# 515                          dilshanwijesooriya  ...     0
# 516                                 ilhamsafeek  ...     0
# 517     kethmini-himasanda-priyankara-095203178  ...     0
# 518                     vishmini-samarawickrama  ...     0
# 519                              chanukadealwis  ...     0
# 521                             humaidfazludeen  ...     0
# 522                         sithirahewaarachchi  ...     0
# 523              chathurya-thennakoon-367590102  ...     0
# 524                              swapnilthaware  ...     0
# 525                   lakshan-dayasiri-67063939  ...     0
# 526                                  malthafali  ...     0
# 527                                azhar-it-cmb  ...     0
# 528                               atulkhatavkar  ...     0
# 529                            yenukashachintha  ...     0
# 530                             milinda-bandara  ...     0
# 531                     sajjad-munawer-485a28aa  ...     0
# 532                                    mawantha  ...     0
# 533                      aakif-kuhafa-057580207  ...     0
# 534                             dhazaan-sheriff  ...     0
# 535    lalisha-sanduwara-samarasinghe-bab9471a4  ...     0
# 536                                   pasinduch  ...     0
# 537               joseph-wimalasuriya-473b97198  ...     0
# 538                       r-om-prakash-400a4485  ...     0
# 539                           avishkasenadheera  ...     0
# 540                               amilaperera97  ...     0
# 541                         hasanka-amarasinghe  ...     0
# 542                   boshan-dayaratne-b2869121  ...     0
# 543                                dilshansilva  ...     0
# 545                            chamathdulshansl  ...     0
# 546                           ashanhewagama2000  ...     0
# 547                 lalith-wijerathne-589114169  ...     0
# 548                                  roohparvar  ...     0
# 550                       david-pasko-6b784a156  ...     0
# 551                    cyber-security-189590201  ...     0
# 552                        toni-bowker-87733121  ...     0
# 553                  vladimir-minakov-09871015a  ...     0
# 555                           swetha-k-413aa1b9  ...     0
# 556                    dunura-dulshan-27708a122  ...     0
# 561                             hashanmadusanka  ...     0
# 562                     rohana-tissera-39b8455b  ...     0
# 563                         satishchandraprasad  ...     0
# 566            ashen-udara-madurawala-561037184  ...     0
# 567                     vaishnavi-a-s-4b7868148  ...     0
# 568                ishara-prasanna-kathriachchi  ...     0
# 569                                bradfordrand  ...     0
# 571                                     muslimk  ...     0
# 572             isuranga-nipun-kumara-70b4b4148  ...     0
# 573                     chalani-perera-a4549a24  ...     0
# 574                                     sihegee  ...     0
# 576                 hirushan-sajindra-01323418b  ...     0
# 577                                   jaredhuet  ...     0
# 578           chathura-wickramasinghe-584260172  ...     0
# 579                         rohini-cha-79b25129  ...     0
# 581                      saran-baskar-ab2b84126  ...     0
# 582                               priyalwalpita  ...     0
# 583                             evindu-shavinda  ...     0
# 584                           kulkarnidhananjay  ...     0
# 585                    mohammed-hasni-3452a5147  ...     0
# 586                      nirushan-sri-198bb3200  ...     0
# 587           sachith-hirimuthugoda-🐐-520b0416a  ...     0
# 588                             galondeanmiller  ...     0
# 590                                parag-shroff  ...     0
# 591                    💥william-taaffe-4618312a  ...     0
# 592                       faisal-kabeer-1998dec  ...     0
# 594                   chethaka-vinura-4092bb199  ...     0
# 595                           doctorsivashankar  ...     0
# 596                vasana-wickremasena-865b2a2b  ...     0
# 597                          yo-kubota-7a052290  ...     0
# 598                deshan-madhushanka-9559141a9  ...     0
# 601                     abdul-rasheed-b45262119  ...     0
# 603             ariyarathna-b-d-t-s-p-b630581a2  ...     0
# 605               arunuwan-yugandhara-38a511200  ...     0
# 607         women-cyber-security-cell-3128b718b  ...     0
# 611             gimhani-paranawithana-363a15176  ...     0
# 614                  chatura-pathirana-31b18a53  ...     0
# 615                        sakunthalagunarathna  ...     0
# 616          vaseekaran-rathakrishnan-8b65a6154  ...     0
# 617                       rishad-refai-19990901  ...     0
# 618                  abilashkanna-sathiamoorthy  ...     0
# 621                               asankauperera  ...     0
# 624                  achintha-tharuka-8a1348205  ...     0
# 626                             dasith-vidanage  ...     0
# 627                       jason-adams-963b11209  ...     0
# 628                                    alobeiwi  ...     0
# 630                                shehan-savio  ...     0
# 631                              pulasthiperera  ...     0
# 632              kavindya-himashi-karunathilake  ...     0
#
# [351 rows x 11 columns]

# %%
Cyber_Data = Cyber_Data.drop(146)
Cyber_Data = Cyber_Data.drop(158)
Cyber_Data = Cyber_Data.drop(180)
Cyber_Data = Cyber_Data.drop(191)
Cyber_Data = Cyber_Data.drop(203)
Cyber_Data = Cyber_Data.drop(208)
Cyber_Data = Cyber_Data.drop(210)
Cyber_Data = Cyber_Data.drop(216)
Cyber_Data = Cyber_Data.drop(217)
Cyber_Data = Cyber_Data.drop(226)
Cyber_Data = Cyber_Data.drop(228)
Cyber_Data = Cyber_Data.drop(234)
Cyber_Data = Cyber_Data.drop(236)
Cyber_Data = Cyber_Data.drop(238)
Cyber_Data = Cyber_Data.drop(281)
Cyber_Data = Cyber_Data.drop(287)
Cyber_Data = Cyber_Data.drop(290)
Cyber_Data = Cyber_Data.drop(291)
Cyber_Data = Cyber_Data.drop(292)
Cyber_Data = Cyber_Data.drop(296)
Cyber_Data = Cyber_Data.drop(297)
Cyber_Data = Cyber_Data.drop(304)
Cyber_Data = Cyber_Data.drop(305)
Cyber_Data = Cyber_Data.drop(311)
Cyber_Data = Cyber_Data.drop(315)
Cyber_Data = Cyber_Data.drop(322)
Cyber_Data = Cyber_Data.drop(333)
Cyber_Data = Cyber_Data.drop(335)
Cyber_Data = Cyber_Data.drop(344)
Cyber_Data = Cyber_Data.drop(347)
Cyber_Data = Cyber_Data.drop(362)
Cyber_Data = Cyber_Data.drop(364)
Cyber_Data = Cyber_Data.drop(368)
Cyber_Data = Cyber_Data.drop(372)
Cyber_Data = Cyber_Data.drop(374)
Cyber_Data = Cyber_Data.drop(377)
Cyber_Data = Cyber_Data.drop(379)
Cyber_Data = Cyber_Data.drop(381)
Cyber_Data = Cyber_Data.drop(383)
Cyber_Data = Cyber_Data.drop(385)
Cyber_Data = Cyber_Data.drop(387)
Cyber_Data = Cyber_Data.drop(388)
Cyber_Data = Cyber_Data.drop(391)
Cyber_Data = Cyber_Data.drop(392)
Cyber_Data = Cyber_Data.drop(394)
Cyber_Data = Cyber_Data.drop(395)
Cyber_Data = Cyber_Data.drop(396)
Cyber_Data = Cyber_Data.drop(397)
Cyber_Data = Cyber_Data.drop(399)
Cyber_Data = Cyber_Data.drop(405)
Cyber_Data = Cyber_Data.drop(406)
Cyber_Data = Cyber_Data.drop(416)
Cyber_Data = Cyber_Data.drop(421)
Cyber_Data = Cyber_Data.drop(422)
Cyber_Data = Cyber_Data.drop(427)
Cyber_Data = Cyber_Data.drop(434)
Cyber_Data = Cyber_Data.drop(439)
Cyber_Data = Cyber_Data.drop(441)
Cyber_Data = Cyber_Data.drop(442)
Cyber_Data = Cyber_Data.drop(445)
Cyber_Data = Cyber_Data.drop(448)
Cyber_Data = Cyber_Data.drop(453)
Cyber_Data = Cyber_Data.drop(460)
Cyber_Data = Cyber_Data.drop(461)
Cyber_Data = Cyber_Data.drop(462)
Cyber_Data = Cyber_Data.drop(465)
Cyber_Data = Cyber_Data.drop(468)
Cyber_Data = Cyber_Data.drop(472)
Cyber_Data = Cyber_Data.drop(475)
Cyber_Data = Cyber_Data.drop(487)
Cyber_Data = Cyber_Data.drop(488)
Cyber_Data = Cyber_Data.drop(499)
Cyber_Data = Cyber_Data.drop(502)
Cyber_Data = Cyber_Data.drop(511)
Cyber_Data = Cyber_Data.drop(514)
Cyber_Data = Cyber_Data.drop(515)
Cyber_Data = Cyber_Data.drop(521)
Cyber_Data = Cyber_Data.drop(530)
Cyber_Data = Cyber_Data.drop(531)
Cyber_Data = Cyber_Data.drop(532)
Cyber_Data = Cyber_Data.drop(536)
Cyber_Data = Cyber_Data.drop(537)
Cyber_Data = Cyber_Data.drop(538)
Cyber_Data = Cyber_Data.drop(547)
Cyber_Data = Cyber_Data.drop(550)
Cyber_Data = Cyber_Data.drop(551)
Cyber_Data = Cyber_Data.drop(555)
Cyber_Data = Cyber_Data.drop(556)
Cyber_Data = Cyber_Data.drop(561)
Cyber_Data = Cyber_Data.drop(566)
Cyber_Data = Cyber_Data.drop(569)
Cyber_Data = Cyber_Data.drop(572)
Cyber_Data = Cyber_Data.drop(573)
Cyber_Data = Cyber_Data.drop(577)
Cyber_Data = Cyber_Data.drop(578)
Cyber_Data = Cyber_Data.drop(582)
Cyber_Data = Cyber_Data.drop(583)
Cyber_Data = Cyber_Data.drop(584)
Cyber_Data = Cyber_Data.drop(585)
Cyber_Data = Cyber_Data.drop(587)
Cyber_Data = Cyber_Data.drop(590)
Cyber_Data = Cyber_Data.drop(594)
Cyber_Data = Cyber_Data.drop(595)
Cyber_Data = Cyber_Data.drop(596)
Cyber_Data = Cyber_Data.drop(597)
Cyber_Data = Cyber_Data.drop(601)
Cyber_Data = Cyber_Data.drop(605)
Cyber_Data = Cyber_Data.drop(615)
Cyber_Data = Cyber_Data.drop(617)
Cyber_Data = Cyber_Data.drop(618)
Cyber_Data = Cyber_Data.drop(624)
Cyber_Data = Cyber_Data.drop(628)
Cyber_Data = Cyber_Data.drop(631)

# %%
Cyber_Data.shape
# Out:
# (396, 11)

# %%
Cyber_Data.insert(10,'Target','Cyber Security')

# %%
Cyber_Data = Cyber_Data.drop(['organization_title_1','label'], axis=1)

# %%
Cyber_Data

# %%
Cyber_Data.to_csv(r'/content/drive/MyDrive/Research Dataset/processed_data/Added_Target/Cyber_Data_processed_WithTarget_Value.csv')

# %%
label, other_labels, countpos, countneg = check_Avalaiblity(MOB_Data,"Mobile Application Developer")

# %%
label2, other_labels2, countpos2, countneg2 = check_Avalaiblity(MOB_Data,"Associate Software Engineer")

# %%
other_labels
# Out:
# ['Associate Software Engineer',
#  'Quality Assurance Engineer',
#  'Wordpress Developer',
#  'Mobile Application Engineer',
#  'Vlogger',
#  ' php laravel web development Summer training',
#  ' Mobile Application Engineer',
#  'nan',
#  'IT Specialist',
#  'Director Of Operations',
#  'Student Expert',
#  'nan',
#  'Brand ambassador',
#  'Senior Software Engineer',
#  'Associate Software Engineer',
#  'Associate UI/ UX Engineer ',
#  'Application Developer',
#  'Software Engineer',
#  'Undergraduate Student',
#  'Associate Software Engineer',
#  'Senior Software Engineer',
#  'Associate Software Engineer',
#  'Associate Software Engineer',
#  'Senior Full Stack Software Engineer',
#  'Game Developer',
#  'Senior Software Engineer',
#  'Mobile/Web Application Developer',
#  'Technical Lead',
#  'Team Lead',
#  'Application Developer',
#  'Freelance Development',
#  'nan',
#  'Mobile Tech Lead',
#  'Software Engineer - Android',
#  'Freelance Software Developer',
#  'nan',
#  'Senior Software Engineer',
#  'Associate Mobile Developer',
#  'Software Engineer(Mobile Application IOS)',
#  'Web Developer',
#  'Software Engineer Intern',
#  'Software Engineer',
#  'Undergraduate',
#  'Business Owner',
#  'Technical Lead',
#  'Software Engineer',
#  'Software Engineer',
#  'Intern Mobile developer',
#  'Mobile & Web Application Developer',
#  'Assistant Lecturer',
#  'Software Engineer Intern',
#  'Software Engineer',
#  'Software Engineer Intern',
#  'Web Developer',
#  'Developer',
#  'Human Resources Executive',
#  'Senior Software Engineer',
#  'Mobile Application Development Consultant',
#  'iOS Engineer',
#  'Associate Software Developer',
#  'Technical Lead',
#  'Founder',
#  'Full Stack Mobile Developer',
#  'Senior Software Engineer',
#  'Software Developer Internship',
#  'Founder',
#  'nan',
#  'Software Engineer',
#  'nan',
#  'Co-Founder',
#  'Software Engineer',
#  'Software Developer and Mobile Application',
#  'Senior Software Engineer',
#  'nan',
#  'Director / Chief Technology Officer',
#  'Member',
#  'Associate Technical Lead',
#  'Bilişim Teknolojileri Öğretmeni',
#  'Full Stack Developer',
#  'Manager | Tech Lead',
#  'Freelance Software Engineer',
#  'Mobile Developer',
#  'Co-Founder',
#  'Software Engineer',
#  'Mobile application developer',
#  'Application Developer',
#  'Senior Software Engineer',
#  'Senior Software Engineer',
#  'Software Engineer',
#  'Web Developer',
#  'Secretary',
#  'Flutter developer',
#  'Android Developer',
#  'SDE-3',
#  'Application Developer',
#  'Software Engineer',
#  'Senior Software Engineer',
#  'Android Developer',
#  'Director - Technical ',
#  'Senior Software Engineer',
#  'Software Engineer',
#  'MobileApplication',
#  'Software Engineer',
#  'Associate Laravel Developer',
#  'Founder',
#  'Full Stack Web Developer Intern',
#  'Junior Software Engineer',
#  'Freelance Web Developer',
#  'Director',
#  'Software Developer',
#  'Wordpress developer',
#  'Software Development Consultant',
#  'Associate Software Engineer',
#  'Oracle Applications Consultant - WMS',
#  'nan',
#  'Software Application Developer',
#  'Software Engineer',
#  'Associate Tech lead',
#  'Senior Software Engineer',
#  'Software Engineer',
#  'IFS Technical Consultant',
#  'Vice President Of Business Development',
#  'React Native Developer',
#  'Software Engineer',
#  'Software Engineer',
#  'Web Application Developer',
#  'Software Engineer',
#  'Senior Software Engineer',
#  'Freelance Integration Consultant',
#  'Software Engineer',
#  'Senior Software Engineer',
#  'Senior Technical Lead',
#  'Software Engineer (Mobile Applications) -Remote',
#  'Mobil Uygulama Geliştirici',
#  'Senior Software Engineer',
#  'Software Engineer',
#  'Android Developer',
#  'Wordpress Developer',
#  'Mobile Developer - Android',
#  'Software Developer',
#  'Software Engineer - Mobile Application Development',
#  'Senior Software Engineer',
#  'Software Engineer',
#  'Computer Engineer',
#  'Software Developer',
#  'Android Developer',
#  'Senior Software Engineer',
#  'Senior Software Engineer',
#  'nan',
#  'Android Developer',
#  'Senior Software Engineer',
#  'Software Engineer',
#  'Mobile Software Specialist',
#  'Software Engineer',
#  'Associate Tech Lead',
#  'Software Engineering Trainee',
#  'Android Developer',
#  'Senior Software Architect',
#  'Software Engineer',
#  'Software Engineer',
#  'Software Engineer',
#  'Senior Software Engineer - Full Stack',
#  'Wordpress Developer',
#  'Senior iOS Developer ',
#  'Back End Developer',
#  'Senior IOS Android Developer',
#  'Full Stack Developer',
#  'Software Tester',
#  'Technical Lead',
#  'Head Of Software Development',
#  'nan',
#  'Web and Mobile Developer',
#  'Professional Freelancer',
#  'CEO',
#  'Co-Founder & Managing Director',
#  'Software Engineer',
#  'Mobile Developer',
#  'nan',
#  'Software Engineer',
#  'Software Engineer',
#  'Senior Software Engineer(mobile)',
#  'Senior Software Engineer',
#  'nan',
#  'Undergraduate Student',
#  'Student',
#  'nan',
#  'Flutter Developer',
#  'Software Engineer',
#  'Flutter developer',
#  'Software Engineer',
#  'Graduate Trainee',
#  'Application Developer',
#  'Flutter Developer',
#  'Software Engineer',
#  'Microsoft Learn Student Ambassador',
#  'Co-Founder',
#  'Software Engineer',
#  'Senior Front-End Engineer',
#  'Senior Technical Consultant (Remote)',
#  'Lead Software Engineer',
#  'Software Developer',
#  'Software Engineer',
#  'Remote - Full Stack Developer - Mobile and Web Application',
#  'Hardware Technician',
#  'Senior Software Engineer',
#  'Senior Software Engineer',
#  'Android Developer',
#  'Mobile application developer ',
#  'nan',
#  'Software Developer',
#  'Software Engineer',
#  'Software Engineer',
#  'Lead Software Development Engineer',
#  'Software Engineer',
#  'iOS Developer',
#  'nan',
#  'Frontend Web Developer',
#  'Senior Software Engineer']

# %%
countpos2
# Out:
# 6

# %%
countpos
# Out:
# 306

# %%
MOB_Data['label'] = label

# %%
MOB_Data_New = MOB_Data.loc[MOB_Data['label']==0]

# %%
MOB_Data_New
# Out:
#                                    id   50  ...         organization_title_1 label
# 0                       anushkapubudu  NaN  ...  Associate Software Engineer     0
# 2                            ruwasoft  NaN  ...   Quality Assurance Engineer     0
# 3    umaibala-thirukeswaran-366b271a1  NaN  ...          Wordpress Developer     0
# 4              ahamed-mujeeb-43a03535  NaN  ...  Mobile Application Engineer     0
# 7                        isurigallage  NaN  ...                      Vlogger     0
# ..                                ...  ...  ...                          ...   ...
# 513                     sahan-monaara  NaN  ...            Software Engineer     0
# 514            sachithra-siriwardhane  NaN  ...                iOS Developer     0
# 516     anuruddhika-hettige-664bb714a  NaN  ...                          NaN     0
# 518                         kavinda98  NaN  ...       Frontend Web Developer     0
# 519                             arzad  NaN  ...     Senior Software Engineer     0
#
# [218 rows x 12 columns]

# %%
def drop_values(dataset,value):
  # Drop row first filter value
  Dropvalue = dataset[dataset['organization_title_1'] == value]
  # Droping the value that filtered above cell
  dataset.drop(Dropvalue.index, inplace= True)
  return dataset

# %%
MOB_Data.shape
# Out:
# (524, 12)

# %%
drop_values(MOB_Data,"Software Engineer")

# %%
MOB_Data.shape
# Out:
# (488, 12)

# %%
drop_values(MOB_Data,"Senior Software Engineer")

# %%
MOB_Data.shape
# Out:
# (465, 12)

# %%
drop_values(MOB_Data,"Associate Software Engineer")

# %%
MOB_Data.shape
# Out:
# (459, 12)

# %%
label3, other_labels3, countpos3, countneg3 = check_Avalaiblity(MOB_Data,"Mobile Application Developer")

# %%
countpos3
# Out:
# 306

# %%
countneg3
# Out:
# 153

# %%
other_labels3

# %%
MOB_Data.shape
# Out:
# (459, 12)

# %%
MOB_Data = MOB_Data.dropna(subset=['organization_title_1'])

# %%
MOB_Data.shape
# Out:
# (444, 12)

# %%
label4, other_labels4, countpos4, countneg4 = check_Avalaiblity(MOB_Data,"Mobile Application Developer")

# %%
other_labels4
# Out:
# ['Quality Assurance Engineer',
#  'Wordpress Developer',
#  'Mobile Application Engineer',
#  'Vlogger',
#  ' php laravel web development Summer training',
#  ' Mobile Application Engineer',
#  'IT Specialist',
#  'Director Of Operations',
#  'Student Expert',
#  'Brand ambassador',
#  'Associate UI/ UX Engineer ',
#  'Application Developer',
#  'Undergraduate Student',
#  'Senior Full Stack Software Engineer',
#  'Game Developer',
#  'Mobile/Web Application Developer',
#  'Technical Lead',
#  'Team Lead',
#  'Application Developer',
#  'Freelance Development',
#  'Mobile Tech Lead',
#  'Software Engineer - Android',
#  'Freelance Software Developer',
#  'Associate Mobile Developer',
#  'Software Engineer(Mobile Application IOS)',
#  'Web Developer',
#  'Software Engineer Intern',
#  'Undergraduate',
#  'Business Owner',
#  'Technical Lead',
#  'Intern Mobile developer',
#  'Mobile & Web Application Developer',
#  'Assistant Lecturer',
#  'Software Engineer Intern',
#  'Software Engineer Intern',
#  'Web Developer',
#  'Developer',
#  'Human Resources Executive',
#  'Mobile Application Development Consultant',
#  'iOS Engineer',
#  'Associate Software Developer',
#  'Technical Lead',
#  'Founder',
#  'Full Stack Mobile Developer',
#  'Software Developer Internship',
#  'Founder',
#  'Co-Founder',
#  'Software Developer and Mobile Application',
#  'Director / Chief Technology Officer',
#  'Member',
#  'Associate Technical Lead',
#  'Bilişim Teknolojileri Öğretmeni',
#  'Full Stack Developer',
#  'Manager | Tech Lead',
#  'Freelance Software Engineer',
#  'Mobile Developer',
#  'Co-Founder',
#  'Mobile application developer',
#  'Application Developer',
#  'Web Developer',
#  'Secretary',
#  'Flutter developer',
#  'Android Developer',
#  'SDE-3',
#  'Application Developer',
#  'Android Developer',
#  'Director - Technical ',
#  'MobileApplication',
#  'Associate Laravel Developer',
#  'Founder',
#  'Full Stack Web Developer Intern',
#  'Junior Software Engineer',
#  'Freelance Web Developer',
#  'Director',
#  'Software Developer',
#  'Wordpress developer',
#  'Software Development Consultant',
#  'Oracle Applications Consultant - WMS',
#  'Software Application Developer',
#  'Associate Tech lead',
#  'IFS Technical Consultant',
#  'Vice President Of Business Development',
#  'React Native Developer',
#  'Web Application Developer',
#  'Freelance Integration Consultant',
#  'Senior Technical Lead',
#  'Software Engineer (Mobile Applications) -Remote',
#  'Mobil Uygulama Geliştirici',
#  'Android Developer',
#  'Wordpress Developer',
#  'Mobile Developer - Android',
#  'Software Developer',
#  'Software Engineer - Mobile Application Development',
#  'Computer Engineer',
#  'Software Developer',
#  'Android Developer',
#  'Android Developer',
#  'Mobile Software Specialist',
#  'Associate Tech Lead',
#  'Software Engineering Trainee',
#  'Android Developer',
#  'Senior Software Architect',
#  'Senior Software Engineer - Full Stack',
#  'Wordpress Developer',
#  'Senior iOS Developer ',
#  'Back End Developer',
#  'Senior IOS Android Developer',
#  'Full Stack Developer',
#  'Software Tester',
#  'Technical Lead',
#  'Head Of Software Development',
#  'Web and Mobile Developer',
#  'Professional Freelancer',
#  'CEO',
#  'Co-Founder & Managing Director',
#  'Mobile Developer',
#  'Senior Software Engineer(mobile)',
#  'Undergraduate Student',
#  'Student',
#  'Flutter Developer',
#  'Flutter developer',
#  'Graduate Trainee',
#  'Application Developer',
#  'Flutter Developer',
#  'Microsoft Learn Student Ambassador',
#  'Co-Founder',
#  'Senior Front-End Engineer',
#  'Senior Technical Consultant (Remote)',
#  'Lead Software Engineer',
#  'Software Developer',
#  'Remote - Full Stack Developer - Mobile and Web Application',
#  'Hardware Technician',
#  'Android Developer',
#  'Mobile application developer ',
#  'Software Developer',
#  'Lead Software Development Engineer',
#  'iOS Developer',
#  'Frontend Web Developer']

# %%
countneg4
# Out:
# 138

# %%
pd.set_option('max_rows', 99999)
pd.set_option('max_colwidth', 400)
pd.describe_option('max_colwidth')
# Out:
# display.max_colwidth : int or None
#     The maximum width in characters of a column in the repr of
#     a pandas data structure. When the column overflows, a "..."
#     placeholder is embedded in the output. A 'None' value means unlimited.
#     [default: 50] [currently: 400]

# %%
MOB_Data['label'] = label4
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
MOB_Data_New = MOB_Data.loc[MOB_Data['label']==0]

# %%
MOB_Data_New
# Out:
#                                    id  ... label
# 2                            ruwasoft  ...     0
# 3    umaibala-thirukeswaran-366b271a1  ...     0
# 4              ahamed-mujeeb-43a03535  ...     0
# 7                        isurigallage  ...     0
# 10             esraa-helaly-573548175  ...     0
# 11                         rananjayab  ...     0
# 15            mahmoud-ahmed-69bb051a2  ...     0
# 17                    shanukagayashan  ...     0
# 18                          malshikay  ...     0
# 21           t-himaranga-ponnamperuma  ...     0
# 26               chavika-kodithuwakku  ...     0
# 28             uvini-ahinsa-045500176  ...     0
# 30      chanaka-wijesundara-6b69a8192  ...     0
# 44                            dulajra  ...     0
# 46                 kasun-aththanayake  ...     0
# 49      thashreef-haleemdeen-9a815577  ...     0
# 52                         tcwijekoon  ...     0
# 53                       muhaiminah90  ...     0
# 54          bimsara-bandara-191220160  ...     0
# 63                   harshanlakshitha  ...     0
# 66            dilan-fernando-92413463  ...     0
# 68           ishan-de-silva-9a8189160  ...     0
# 70             eranga-prasad-875b5b55  ...     0
# 77     manul-hiyare-pallege-9b914a197  ...     0
# 78           yasitha-herath-8b49a8123  ...     0
# 79                             ndshwa  ...     0
# 80        abdul-saleem-mohamed-faheem  ...     0
# 87            udara-randika-971205160  ...     0
# 88       madusha-rajapaksha-01472b172  ...     0
# 89                   danutha-fernando  ...     0
# 94     thushal-madhushankha-496590199  ...     0
# 95                  ashan-chathuranga  ...     0
# 97            ishan-randika-36b085122  ...     0
# 98         sathush-chandran-707161197  ...     0
# 101            hilal-safwan-a051291a3  ...     0
# 103      sandeepa-alahakoon-05b7a41a4  ...     0
# 104                 lakmal-jayasuriya  ...     0
# 106             nisansala-sewwandim09  ...     0
# 113          neeshachatulaniravindran  ...     0
# 114        hedrich-fernando-789925195  ...     0
# 121                      sahan-peiris  ...     0
# 123          danushka-perera-9161a663  ...     0
# 126                          jerushan  ...     0
# 127      chathuranga-bopage-320139141  ...     0
# 130                      nipunanushan  ...     0
# 131         ravindu-lakmina-236914188  ...     0
# 136                 chamika-hasaranga  ...     0
# 141     odai-ahmad-al-gmzawe-a262b4b8  ...     0
# 149                madhurangagunadasa  ...     0
# 150                  nishadi-de-zoysa  ...     0
# 165           pradeep-kumara-b4935953  ...     0
# 168             elanur-süer-6b81951a3  ...     0
# 169                    gayanviduranga  ...     0
# 171                         damithark  ...     0
# 177         iresh-madhuranga-16957745  ...     0
# 189                   zhong-xuan-tang  ...     0
# 192    emeraldshancakrawala-54b285184  ...     0
# 198            mariam-ahmed-839323190  ...     0
# 199       rangana-sadaruwan-82410b196  ...     0
# 222         dinesh-nisshanka-78795146  ...     0
# 223                   taha-m-54274ba9  ...     0
# 224                      hossamelsaid  ...     0
# 225             hassan-raza-1a7934153  ...     0
# 226             nihar-ranjan-50736a98  ...     0
# 228         yenuka-madusanka-aa954464  ...     0
# 237      dimesha-wijerathna-5483b1183  ...     0
# 239                            deshan  ...     0
# 245           momen-mahmoud-ab1a991a8  ...     0
# 248                       mhmaarafath  ...     0
# 250       yasith-saminthaka-0263b3108  ...     0
# 251      fathima-ilma-zahil-6404021b9  ...     0
# 253                      farhanjaffer  ...     0
# 257         monali-fernando-704ba515b  ...     0
# 258                  ireshmadhusankha  ...     0
# 260                         tharakadk  ...     0
# 261        madumi-ashanthka-7728941a8  ...     0
# 264                          timashev  ...     0
# 267  hemantha-janaka-bandara-14732124  ...     0
# 272             zahmi-zuhair-77134b32  ...     0
# 275      naveed-sheriffdeen-68135315b  ...     0
# 280                    srimalfernando  ...     0
# 281                      judeshehan94  ...     0
# 286        harshana-viranga-33a313215  ...     0
# 291        pulina-witharana-486859198  ...     0
# 294                           nipunad  ...     0
# 297                          askarmus  ...     0
# 298        isuru-madumadawa-a92987167  ...     0
# 301                      kadir-gorgun  ...     0
# 317              rubab-azim-522061100  ...     0
# 321           praveenkumar-srikanthan  ...     0
# 323       ishara-wijenayaka-58933a1ba  ...     0
# 330       sibongiseni-mxinwa-11822ab5  ...     0
# 331                          janithsg  ...     0
# 341       minura-wijesinghe-30b437154  ...     0
# 346       bavanthinikathiresapillai95  ...     0
# 347           mahmoud-mousa-a4355b192  ...     0
# 358             eslam-mongy-57795b187  ...     0
# 362                    harunayyildizz  ...     0
# 370                jeinilakshanselvan  ...     0
# 373                      manzirhameer  ...     0
# 375    muhammad-saim-hashmi-8234a1197  ...     0
# 383    chandima-jayawickrema-75b14217  ...     0
# 391                        viranjajay  ...     0
# 392            sourav-ranjan-maharana  ...     0
# 394               dina-reda-613991101  ...     0
# 395                           vimilad  ...     0
# 398  prabath-priyadharshana-606958167  ...     0
# 401                       chamila1026  ...     0
# 403              shenali-samaranayake  ...     0
# 408          dimal-govinnage-97aa7a1b  ...     0
# 409       ishara-meegahawala-b155bb26  ...     0
# 413      ashen-senevirathne-5783a6185  ...     0
# 414             ahmed-naeem-2654bb209  ...     0
# 415                        salehzarei  ...     0
# 416                  geenodh-randeera  ...     0
# 418        charindi-dulmini-2667011aa  ...     0
# 431     lakshitha-benaragama-90424756  ...     0
# 438         mahinsa-bhanuka-1a13a3160  ...     0
# 439              alaa-osama-244100220  ...     0
# 444                         shamsalii  ...     0
# 447             ahmed-shaker-40a41995  ...     0
# 449       bagya-kaushallaya-a16828174  ...     0
# 453             athar-hasan-274838203  ...     0
# 456                      alaa-alaraby  ...     0
# 466                        viradhanus  ...     0
# 469                   shanabeywicrema  ...     0
# 474            sahithanelangahdesilva  ...     0
# 481                         zameermfm  ...     0
# 482                        iliasahmed  ...     0
# 483                    hiteash-nikamh  ...     0
# 486                        shanmanage  ...     0
# 488                        halilseran  ...     0
# 491                       doniaashraf  ...     0
# 498    ons-ben-hadj-sghaier-91495519a  ...     0
# 509              talha-sahi-303933156  ...     0
# 512                   imeshpunchihewa  ...     0
# 514            sachithra-siriwardhane  ...     0
# 518                         kavinda98  ...     0
#
# [138 rows x 12 columns]

# %%
MOB_Data = MOB_Data.drop(7)
MOB_Data = MOB_Data.drop(10)
MOB_Data = MOB_Data.drop(15)
MOB_Data = MOB_Data.drop(17)
MOB_Data = MOB_Data.drop(21)
MOB_Data = MOB_Data.drop(26)
MOB_Data = MOB_Data.drop(30)
MOB_Data = MOB_Data.drop(44)
MOB_Data = MOB_Data.drop(52)
MOB_Data = MOB_Data.drop(63)
MOB_Data = MOB_Data.drop(79)
MOB_Data = MOB_Data.drop(80)
MOB_Data = MOB_Data.drop(87)
MOB_Data = MOB_Data.drop(98)
MOB_Data = MOB_Data.drop(101)
MOB_Data = MOB_Data.drop(103)
MOB_Data = MOB_Data.drop(104)
MOB_Data = MOB_Data.drop(106)
MOB_Data = MOB_Data.drop(130)
MOB_Data = MOB_Data.drop(131)
MOB_Data = MOB_Data.drop(150)
MOB_Data = MOB_Data.drop(168)
MOB_Data = MOB_Data.drop(171)
MOB_Data = MOB_Data.drop(177)
MOB_Data = MOB_Data.drop(239)
MOB_Data = MOB_Data.drop(253)
MOB_Data = MOB_Data.drop(257)
MOB_Data = MOB_Data.drop(258)
MOB_Data = MOB_Data.drop(264)
MOB_Data = MOB_Data.drop(267)
MOB_Data = MOB_Data.drop(280)
MOB_Data = MOB_Data.drop(281)
MOB_Data = MOB_Data.drop(291)
MOB_Data = MOB_Data.drop(294)
MOB_Data = MOB_Data.drop(297)
MOB_Data = MOB_Data.drop(301)
MOB_Data = MOB_Data.drop(341)
MOB_Data = MOB_Data.drop(370)
MOB_Data = MOB_Data.drop(373)
MOB_Data = MOB_Data.drop(383)
MOB_Data = MOB_Data.drop(391)
MOB_Data = MOB_Data.drop(395)
MOB_Data = MOB_Data.drop(401)
MOB_Data = MOB_Data.drop(408)
MOB_Data = MOB_Data.drop(438)
MOB_Data = MOB_Data.drop(439)
MOB_Data = MOB_Data.drop(449)
MOB_Data = MOB_Data.drop(469)
MOB_Data = MOB_Data.drop(474)
MOB_Data = MOB_Data.drop(482)
MOB_Data = MOB_Data.drop(488)
MOB_Data = MOB_Data.drop(512)
MOB_Data = MOB_Data.drop(518)

# %%
MOB_Data.shape
# Out:
# (390, 12)

# %%
MOB_Data

# %%
MOB_Data.insert(10,'Target','Mobile App Developer')

# %%
MOB_Data

# %%
MOB_Data = MOB_Data.drop(['organization_title_1','label','50'], axis=1)

# %%
MOB_Data

# %%
MOB_Data.to_csv(r'/content/drive/MyDrive/Research Dataset/processed_data/Added_Target/MOB_Data_processed_WithTarget_Value.csv')

# %%
QA_Data = QA_Data.drop(107)

# %%
QA_Data.insert(10,'Target','Quality Assurance')

# %%
QA_Data

# %%
QA_Data = QA_Data.drop(['organization_title_1','label'], axis=1)

# %%
QA_Data

# %%
QA_Data.to_csv(r'/content/drive/MyDrive/Research Dataset/processed_data/Added_Target/QA_Data_processed_WithTarget_Value.csv')

# %%
# Drop duplicate columns using a unique(key) Value
Data_new = Data.drop_duplicates(subset='id', keep="last")
