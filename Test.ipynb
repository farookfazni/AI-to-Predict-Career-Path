# %% [markdown]
# <a href="https://colab.research.google.com/github/farookfazni/AI-to-Predict-Career-Path/blob/master/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
BA_data = pd.read_csv('/content/drive/MyDrive/Research Dataset/processed_data/Fully_Extracted_Data/BA_processed1.csv')

# %%
BA_data
# Out:
#      Unnamed: 0                               id                   0  \
# 0             0    tharuka-nanayakkara-306986165                Java
# 1             1      lakshika-jayakody-981070170          Leadership
# 2             2    shakkya-jayawardena-113094173          Leadership
# 3             3   krishnica-mariyathas-62a9a8165          Leadership
# 4             4                   romeshwijesiri          Leadership
# ..          ...                              ...                 ...
# 495         495        kavitha-selvasenakurukkal          Leadership
# 496         496    pramila-bopearachchi-49a4356b          Leadership
# 497         497  nethmi-wickramasinghe-890080101    Customer Service
# 498         498     binara-panduwawala-16350b168          Leadership
# 499         499   shalindri-gunasekera-537282211  Project Management
#
#                          1                   2                 3  \
# 0       Project Management    Microsoft Office             MySQL
# ...

# %%
BA_data = BA_data.drop(['Unnamed: 0'], axis=1)

# %%
BA_data
# Out:
#                                   id                   0  \
# 0      tharuka-nanayakkara-306986165                Java
# 1        lakshika-jayakody-981070170          Leadership
# 2      shakkya-jayawardena-113094173          Leadership
# 3     krishnica-mariyathas-62a9a8165          Leadership
# 4                     romeshwijesiri          Leadership
# ..                               ...                 ...
# 495        kavitha-selvasenakurukkal          Leadership
# 496    pramila-bopearachchi-49a4356b          Leadership
# 497  nethmi-wickramasinghe-890080101    Customer Service
# 498     binara-panduwawala-16350b168          Leadership
# 499   shalindri-gunasekera-537282211  Project Management
#
#                          1                   2                 3  \
# 0       Project Management    Microsoft Office             MySQL
# 1         Microsoft Office                   C          Teamwork
# 2                     Java    Microsoft Office             MySQL
# ...

# %%
BA_data = BA_data.iloc[:,:51]

# %%
def check_Missing(dataset, precent):
  #Checking columns with missing data
  Miss_Percent=100*(dataset.isnull().sum()/len(dataset))

  #Sorting the data columns by their percentage in descending order (big to small)
  # by using Miss_Percent>0 it takes values,ore than 0
  # round(1) this is used to round the value to one decimal point .0
  Miss_Percent=Miss_Percent[Miss_Percent>precent].sort_values(ascending=False).round(1)

  #Creating a dataframe to show percentage of missing data and its respective data column in table
  DataFrame=pd.DataFrame(Miss_Percent)
  miss_percent_table=DataFrame.rename(columns={0:'% of Missing Values'})
  MissPercent=miss_percent_table

  #Displaying Missing Value table
  return MissPercent

# %%
check_Missing(BA_data, 0)
# Out:
#     % of Missing Values
# 49                 98.6
# 48                 98.0
# 47                 97.4
# 46                 96.6
# 45                 96.0
# 44                 95.4
# 43                 95.0
# 42                 94.6
# 41                 94.4
# 40                 93.4
# 39                 92.8
# 38                 91.8
# 37                 91.2
# 36                 90.2
# 35                 90.0
# 34                 89.0
# 33                 88.2
# 32                 86.8
# 31                 86.2
# 30                 85.2
# 29                 83.6
# 28                 82.0
# 27                 80.8
# 26                 79.4
# 25                 77.8
# 24                 75.6
# 23                 73.8
# 22                 70.4
# 21                 68.8
# 20                 67.8
# 19                 66.0
# 18                 63.2
# 17                 60.2
# 16                 57.0
# 15                 54.8
# 14                 52.6
# 13                 48.4
# ...

# %%
BA_data
# Out:
#                                                 id  \
# 0                    tharuka-nanayakkara-306986165
# 1                      lakshika-jayakody-981070170
# 2                    shakkya-jayawardena-113094173
# 3                   krishnica-mariyathas-62a9a8165
# 4                                   romeshwijesiri
# 5                       pramodi-de-silva-4a35ba124
# 6                    vishmi-abeywickrama-074b37193
# 7                     tharusha-chankamie-35017b171
# 8                                     dimagiperera
# 9                     nithya-seneviratne-a9277019b
# 10                   samudhini-kolonnage-9413a3113
# 11                  sandesh-dedunupitiya-35513b179
# 12                      dihan-dayasagara-620b87153
# 13                                   sheharagrabau
# 14                         hasni-hussain-2a903a169
# 15                            anuththararathnayake
# 16                       kalpana-desilva-a1550918b
# ...

# %%
# oldcols = {'col1':['a','a','b','b'], 'col2':['c','d','c','d'], 'col3':[1,2,3,4]}
# a = pd.DataFrame(oldcols)  

newf0 = BA_data.pivot(index='0', columns='id', values='0')
# newf0.columns = newf0.columns.droplevel(0)
newf0
# Out:
# id                         aadhil-fazal-53b82b139 aamir-jawfer  \
# 0
# NaN                                           NaN          NaN
# Accounting                                    NaN          NaN
# Analytical Skills                             NaN          NaN
# Business Analysis                             NaN          NaN
# Business Requirements                         NaN          NaN
# C                                             NaN          NaN
# Cascading Style Sheets CSS                    NaN          NaN
# Communication                                 NaN          NaN
# Critical Thinking                             NaN          NaN
# Customer Service                              NaN          NaN
# Data Mining                                   NaN          NaN
# Easily Adaptable                              NaN          NaN
# English                                       NaN          NaN
# HTML                                          NaN          NaN
# ...

# %%
newf1 = BA_data.pivot(index='1', columns='id', values='1')
newf1
# Out:
# id                               aadhil-fazal-53b82b139 aamir-jawfer  \
# 1
# NaN                                                 NaN          NaN
# Accounting                                          NaN          NaN
# Agile Methodologies                                 NaN          NaN
# Analytical Skills                                   NaN          NaN
# Android Development                                 NaN          NaN
# Business Analysis                                   NaN          NaN
# Business Development                                NaN          NaN
# C                                                   NaN            C
# Cascading Style Sheets CSS                          NaN          NaN
# Communication                                       NaN          NaN
# Compere                                             NaN          NaN
# Customer Service                                    NaN          NaN
# ...

# %%
pd.set_option('max_rows', 99999)
pd.set_option('max_colwidth', 400)
pd.describe_option('max_colwidth')
# Out:
# display.max_colwidth : int or None
#     The maximum width in characters of a column in the repr of
#     a pandas data structure. When the column overflows, a "..."
#     placeholder is embedded in the output. A 'None' value means unlimited.
#     [default: 50] [currently: 400]

# %%
# frames = [newf0, newf1]
# result = pd.concat(frames)
# result

# %%
results = newf0.combine_first(newf1)
results
# Out:
# id                               aadhil-fazal-53b82b139 aamir-jawfer  \
# NaN                                                 NaN          NaN
# Accounting                                          NaN          NaN
# Agile Methodologies                                 NaN          NaN
# Analytical Skills                                   NaN          NaN
# Android Development                                 NaN          NaN
# Business Analysis                                   NaN          NaN
# Business Development                                NaN          NaN
# Business Requirements                               NaN          NaN
# C                                                   NaN            C
# Cascading Style Sheets CSS                          NaN          NaN
# Communication                                       NaN          NaN
# Compere                                             NaN          NaN
# Critical Thinking                                   NaN          NaN
# ...

# %%
# for i in range(0,49):
#   newf = BA_data.pivot(index=i, columns=id, values=i)
#   newf = newf.combine_first(newf)

# %%
# df.head(1).combine_first(df.tail(1))
